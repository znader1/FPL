# %%
#Import Libraries
import os
import sqlite3
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Users/ziadNader/Desktop/Personal Projects/Fantasy Premier League/Notebooks'

# %%
#Creata SQL query
#%%
#Establish the conectionCreate your connection.
cnx = sqlite3.connect('../Data/SQLDB/fpl.db')
players_df = pd.read_sql_query("SELECT * FROM PLAYERS", cnx)
#teams_df = pd.read_sql_query("SELECT * FROM TEAMS", cnx)

# %%
players_df.shape
# Out:
# (2783, 54)

# %%
players_df['date'] = pd.to_datetime(players_df['date'])

# %%
players_df_ts = players_df.set_index('date').sort_index()

# %%
players_df_ts[players_df_ts['web_name']=='Son']['points_per_game'].plot()

# %%
players_df_ts.index.max()
# Out:
# Timestamp('2020-10-05 00:00:00')

# %%
players_df_ts.index.value_counts(dropna=False)
# Out:
# 2020-07-31    666
# 2020-10-05    562
# 2020-10-01    556
# 2020-09-09    511
# 2020-08-26    488
# Name: date, dtype: int64

# %%
players_df_ts.head()
# Out:
#             assists  bonus  bps  chance_of_playing_next_round  \
# date
# 2020-07-31       10      9  394                         100.0
# 2020-07-31        0      0    0                           0.0
# 2020-07-31        0      0    7                           NaN
# 2020-07-31        0      0   23                           NaN
# 2020-07-31        0      0    0                         100.0
#
#             chance_of_playing_this_round  clean_sheets    code  \
# date
# 2020-07-31                         100.0             9  201666
# 2020-07-31                           0.0             0  432705
# 2020-07-31                           NaN             0  466955
# 2020-07-31                           NaN             0  244723
# 2020-07-31                         100.0             0  221272
#
#             cost_change_event  cost_change_event_fall  cost_change_start  ...  \
# date                                                                      ...
# 2020-07-31                  0                       0                 -2  ...
# 2020-07-31                  0                       0                  0  ...
# 2020-07-31                  0                       0                  0  ...
# 2020-07-31                  0                       0                  0  ...
# 2020-07-31                  0                       0                 -1  ...
#
#             threat  total_points  transfers_in  transfers_in_event  \
# date
# 2020-07-31   893.0           133        730142                   0
# 2020-07-31     0.0             0          1323                   0
# 2020-07-31     2.0             2           580                   0
# 2020-07-31     2.0             4          6101                   0
# 2020-07-31     0.0             0         35233                   0
#
#             transfers_out  transfers_out_event  value_form value_season  \
# date
# 2020-07-31         613738                    0         0.4         22.9
# 2020-07-31           1185                    0         0.0          0.0
# 2020-07-31            425                    0         0.0          0.4
# 2020-07-31           3603                    0         0.2          1.0
# 2020-07-31          14548                    0         0.0          0.0
#
#             web_name  yellow_cards
# date
# 2020-07-31    Barnes             0
# 2020-07-31      Daly             0
# 2020-07-31  Pierrick             0
# 2020-07-31  Mitchell             1
# 2020-07-31     Woods             0
#
# [5 rows x 53 columns]

# %%
players_df_ts.nlargest(10, 'points_per_game')
# Out:
#             assists  bonus  bps  chance_of_playing_next_round  \
# date
# 2020-10-05        1      3   51                         100.0
# 2020-10-01        1      2   39                           NaN
# 2020-10-05        1      1   41                         100.0
# 2020-10-05        3      3  129                           NaN
# 2020-10-05        1      5  162                         100.0
# 2020-10-01        1      2   66                           NaN
# 2020-10-05        6      6  159                           NaN
# 2020-10-01        0      6  140                          75.0
# 2020-10-01        0      3   69                           NaN
# 2020-10-01        0      5  129                           NaN
#
#             chance_of_playing_this_round  clean_sheets    code  \
# date
# 2020-10-05                         100.0             1  172850
# 2020-10-01                           NaN             0  103025
# 2020-10-05                         100.0             0   80226
# 2020-10-05                           NaN             2  114283
# 2020-10-05                          25.0             0   85971
# 2020-10-01                           NaN             2  149484
# 2020-10-05                           NaN             0   78830
# 2020-10-01                           NaN             1  101668
# 2020-10-01                           NaN             2  199798
# 2020-10-01                           NaN             1  177815
#
#             cost_change_event  cost_change_event_fall  cost_change_start  ...  \
# date                                                                      ...
# 2020-10-05                  1                      -1                  1  ...
# 2020-10-01                 -1                       1                 -1  ...
# 2020-10-05                  0                       0                 -3  ...
# 2020-10-05                  0                       0                  0  ...
# 2020-10-05                  0                       0                  0  ...
# 2020-10-01                  0                       0                  0  ...
# 2020-10-05                  1                      -1                  1  ...
# 2020-10-01                  0                       0                  0  ...
# 2020-10-01                  0                       0                  0  ...
# 2020-10-01                  1                      -1                  4  ...
#
#             threat  total_points  transfers_in  transfers_in_event  \
# date
# 2020-10-05    27.0            18        388077              317291
# 2020-10-01    30.0            12        193135              128379
# 2020-10-05    56.0            12         25720               18332
# 2020-10-05   170.0            35        326169              164768
# 2020-10-05   181.0            45       1583672              532333
# 2020-10-01    40.0            22        114784               66009
# 2020-10-05   269.0            44        733184              214606
# 2020-10-01   129.0            32        634143              259351
# 2020-10-01    33.0            21        221196               74846
# 2020-10-01   223.0            31       1970581              601716
#
#             transfers_out  transfers_out_event  value_form value_season  \
# date
# 2020-10-05          55134                 6272         0.8          3.2
# 2020-10-01          94823                18078         0.7          1.4
# 2020-10-05         161440                 3700         0.6          2.3
# 2020-10-05         234775                16683         1.7          5.0
# 2020-10-05        2062308                63407         1.2          5.0
# 2020-10-01          30346                11006         2.2          4.4
# 2020-10-05         443256                13068         1.0          4.2
# 2020-10-01         485202                89099         1.1          3.2
# 2020-10-01          39443                15694         2.3          4.7
# 2020-10-01         196883                27909         1.4          4.2
#
#                  web_name  yellow_cards
# date
# 2020-10-05       Chilwell             0
# 2020-10-01         Mahrez             0
# 2020-10-05         Aurier             0
# 2020-10-05       Grealish             0
# 2020-10-05            Son             0
# 2020-10-01          Mings             1
# 2020-10-05           Kane             0
# 2020-10-01          Vardy             0
# 2020-10-01          Konsa             0
# 2020-10-01  Calvert-Lewin             0
#
# [10 rows x 53 columns]

# %%
players_df.columns
# Out:
# Index(['assists', 'bonus', 'bps', 'chance_of_playing_next_round',
#        'chance_of_playing_this_round', 'clean_sheets', 'code',
#        'cost_change_event', 'cost_change_event_fall', 'cost_change_start',
#        'cost_change_start_fall', 'creativity', 'dreamteam_count',
#        'element_type', 'ep_next', 'ep_this', 'event_points', 'first_name',
#        'form', 'goals_conceded', 'goals_scored', 'ict_index', 'i_d',
#        'in_dreamteam', 'influence', 'minutes', 'news', 'news_added',
#        'now_cost', 'own_goals', 'penalties_missed', 'penalties_saved', 'photo',
#        'points_per_game', 'red_cards', 'saves', 'second_name',
#        'selected_by_percent', 'special', 'squad_number', 'status', 'team',
#        'team_code', 'threat', 'total_points', 'transfers_in',
#        'transfers_in_event', 'transfers_out', 'transfers_out_event',
#        'value_form', 'value_season', 'web_name', 'yellow_cards', 'date'],
#       dtype='object')

# %%
players_df_ts.loc['2020-10-05 00:00:00'].nlargest(10, 'points_per_game')\
[['first_name', 'web_name', 'team_code','points_per_game','minutes']]
# Out:
#             first_name       web_name  team_code  points_per_game  minutes
# date
# 2020-10-05    Benjamin       Chilwell          8             18.0       90
# 2020-10-05       Serge         Aurier          6             12.0       90
# 2020-10-05        Jack       Grealish          7             11.7      270
# 2020-10-05   Heung-Min            Son          6             11.2      297
# 2020-10-05       Harry           Kane          6             11.0      353
# 2020-10-05     Mohamed          Salah         14             10.2      360
# 2020-10-05     Dominic  Calvert-Lewin         11              9.2      338
# 2020-10-05         Max         Kilman         39              9.0       90
# 2020-10-05  Jorge Luiz       Jorginho          8              9.0      252
# 2020-10-05       James      Rodríguez         11              8.8      329
