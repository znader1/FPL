# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
list_scores = [1817, 1988 , 1438 , 1619 , 2046 , 1622 , 2077 , 1560]
list_seasons = ['12/13', '13/14', '14/15', '15/16' , '17/18', '18/19', '19/20', '20/21']
list_rank = [917803, 1087447, 2790613, 2295696, 825027, 5081061, 1107658, 697369]

# %%
len(list_scoress)
# Out:
# 8

# %%
len(list_seasons)
# Out:
# 8

# %%
len(list_rank)
# Out:
# 8

# %%
plt.bar(x = list_seasons, height=list_scores, width=0.4)
plt.axhline(y=1560, color='r', linestyle='--');

# %%
plt.bar(x = list_seasons, height=list_rank, width=0.4)
plt.axhline(y=1560, color='r', linestyle='--');

# %%
list_scores
# Out:
# [1817, 1988, 1438, 1619, 2046, 1622, 2077, 1560]

# %%
(np.array(list_scores[:7])/38).round()
# Out:
# array([48., 52., 38., 43., 54., 43., 55.])

# %%
np.array(list_scores[7:])/26
# Out:
# array([60.])

# %%
full_array = np.append((np.array(list_scores[:7])/38).round(), np.array(list_scores[7:])/26)

# %%
full_array
# Out:
# array([48., 52., 38., 43., 54., 43., 55., 60.])

# %%
plt.bar(x = list_seasons, height=full_array, width=0.4)
plt.axhline(y=60, color='r', linestyle='--');
#for i in rane
#plt.annotate(text=str())
