# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
from collections import Counter
pd.options.display.max_columns=64

# %% [markdown]
# # Collect players data from latest update

# %%
fpl_all_data_21_24 = pd.read_csv('/Users/ziadNader/Desktop/Personal Projects/Fantasy Premier League/data/processed/all_players_years.csv', 
                                 index_col=0)

# %%
fpl_all_data_21_24.sort_values(by='date', inplace=True)

# %%
fpl_all_data_21_24['date'].max()
# Out:
# '2024-09-05'

# %%
fpl_all_data_21_24.shape
# Out:
# (51187, 54)

# %%
fpl_all_data_21_24.isna().sum()
# Out:
# assists                             0
# bonus                               0
# bps                                 0
# chance_of_playing_next_round    20098
# chance_of_playing_this_round    20990
# clean_sheets                        0
# code                                0
# cost_change_event                   0
# cost_change_event_fall              0
# cost_change_start                   0
# cost_change_start_fall              0
# creativity                          0
# dreamteam_count                     0
# element_type                        0
# ep_next                             3
# ep_this                          1764
# event_points                        0
# first_name                          0
# form                                0
# goals_conceded                      0
# goals_scored                        0
# ict_index                           0
# i_d                                 0
# in_dreamteam                        0
# influence                           0
# ...

# %%
fpl_all_data_21_24
# Out:
#        assists  bonus  bps  chance_of_playing_next_round  \
# 11164        0     11  625                           NaN
# 11527        0      0    0                           NaN
# 11526        0      0    0                           NaN
# 11525        0      6  376                           NaN
# 11524        0      0   47                           NaN
# ...        ...    ...  ...                           ...
# 21069        0      0    0                           NaN
# 21070        0      0    7                         100.0
# 21071        0      0   21                           NaN
# 21073        0      0   12                           NaN
# 21029        0      0    0                           NaN
#
#        chance_of_playing_this_round  clean_sheets    code  cost_change_event  \
# 11164                           NaN            11   80201                  0
# 11527                           NaN             0   81441                  0
# ...

# %%
* selected period with 23/24 : 13/08/24
* Trend analysis

# %%
fpl_all_data_21_24[fpl_all_data_21_24['second_name']=='Haaland']
# Out:
#        assists  bonus   bps  chance_of_playing_next_round  \
# 15546        0      3    48                           NaN
# 2503         1      3    64                           NaN
# 36716        1      6   165                           NaN
# 40896        1     12   278                           NaN
# 45686        1     12   278                           NaN
# 6535         1     12   307                           NaN
# 23286        3     15   409                           NaN
# 24538        3     15   432                           NaN
# 29440        3     18   485                          75.0
# 5900         3     18   485                          75.0
# 3142         3     19   517                         100.0
# 14937        3     22   568                         100.0
# 46351        3     23   588                         100.0
# 14236        3     26   704                         100.0
# 4589         4     26   733                         100.0
# ...

# %% [markdown]
# # Predict next game outcome in terms of bonus points/points per game
