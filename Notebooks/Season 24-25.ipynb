# %%
import sys
import os
import pandas as pd
import matplotlib as plt
# Prevent truncation of columns in notebook
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# Go up to the project root (assuming you're in /notebooks)
project_root = os.path.abspath(os.path.join(os.path.dirname(os.getcwd()), '.'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.historical_loader import load_fpl_history

seasons = ['2023-24', '2024-25']
df = load_fpl_history('../data/raw/Fantasy-Premier-League/data', seasons)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[9], line 4
#       1 from src.historical_loader import load_fpl_history
#       3 seasons = ['2023-24', '2024-25']
# ----> 4 df = load_fpl_history('../data/raw/Fantasy-Premier-League/data', seasons)
#       5 df.head()
#
# File ~/Desktop/Personal Projects/Fantasy Premier League/src/historical_loader.py:14, in load_fpl_history(base_path, seasons)
#      12 path = os.path.join(base_path, season, 'gws', 'merged_gw.csv')
#      13 if os.path.exists(path):
# ---> 14     df = pd.read_csv(path, encoding='latin1')
#      15     df['season'] = season
#      16     all_data.append(df)
#
# File ~/Desktop/Personal Projects/Fantasy Premier League/FPL_env/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable
