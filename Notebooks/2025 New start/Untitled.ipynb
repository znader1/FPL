# %%
import sys
import os

# Go up to the project root (assuming you're in /notebooks)
project_root = os.path.abspath(os.path.join(os.path.dirname(os.getcwd()), '.'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.historical_loader import load_fpl_history

df = load_fpl_history('data/raw/Fantasy-Premier-League/data')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from src.historical_loader import load_fpl_history
#       3 df = load_fpl_history('data/raw/Fantasy-Premier-League/data')
#       4 df.head()
#
# ModuleNotFoundError: No module named 'src'

# %%
# 01_explore_historical_data.ipynb

# 🔧 Fix Python path so we can import from src/
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# ✅ Now import the historical loader
from src.historical_loader import load_fpl_history

# 📁 Set the path to where you cloned the Vaastav repo
data_path = 'data/raw/Fantasy-Premier-League/data'

# 📊 Load historical data across all seasons
df = load_fpl_history(base_path=data_path)

# 🧹 Preview the dataset
print(f"Shape: {df.shape}")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 12
#       9     sys.path.append(project_root)
#      11 # ✅ Now import the historical loader
# ---> 12 from src.historical_loader import load_fpl_history
#      14 # 📁 Set the path to where you cloned the Vaastav repo
#      15 data_path = 'data/raw/Fantasy-Premier-League/data'
#
# ModuleNotFoundError: No module named 'src'
