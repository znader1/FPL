# %%
* Exctract all the players
* Add some features ( like next opponent FDR)  and next 5 games average or number of home/away games
* Extract my team 
* suggest a transfer based on characteristics

# %%
import pandas as pd

# %%
fixtures_list = pd.read_json('/Users/ziadNader/Desktop/Personal Projects/Fantasy Premier League/data/raw/fixtures/fixtures.json')

# %%
fixtures_list
# Out:
#         code  event  finished  finished_provisional   id  \
# 0    2367869    NaN     False                 False  332
# 1    2367792    NaN     False                 False  255
# 2    2367874    NaN     False                 False  337
# 3    2367876    NaN     False                 False  339
# 4    2367538    1.0      True                  True    1
# ..       ...    ...       ...                   ...  ...
# 375  2367913   38.0     False                 False  376
# 376  2367914   38.0     False                 False  377
# 377  2367915   38.0     False                 False  378
# 378  2367916   38.0     False                 False  379
# 379  2367917   38.0     False                 False  380
#
#                  kickoff_time  minutes  provisional_start_time  started  \
# 0                         NaT        0                    True      NaN
# 1                         NaT        0                    True      NaN
# ...

# %%
fixtures_list[fixtures_list['finished']]['stats'].iloc[0]
# Out:
# [{'identifier': 'goals_scored',
#   'a': [{'value': 2, 'element': 355}, {'value': 1, 'element': 365}],
#   'h': []},
#  {'identifier': 'assists',
#   'a': [{'value': 1, 'element': 343}, {'value': 1, 'element': 365}],
#   'h': []},
#  {'identifier': 'own_goals', 'a': [], 'h': []},
#  {'identifier': 'penalties_saved', 'a': [], 'h': []},
#  {'identifier': 'penalties_missed', 'a': [], 'h': []},
#  {'identifier': 'yellow_cards', 'a': [], 'h': []},
#  {'identifier': 'red_cards', 'a': [], 'h': [{'value': 1, 'element': 184}]},
#  {'identifier': 'saves',
#   'a': [{'value': 1, 'element': 352}],
#   'h': [{'value': 5, 'element': 596}]},
#  {'identifier': 'bonus',
#   'a': [{'value': 3, 'element': 355},
#    {'value': 2, 'element': 365},
#    {'value': 1, 'element': 342}],
#   'h': []},
#  {'identifier': 'bps',
#   'a': [{'value': 56, 'element': 355},
#    {'value': 42, 'element': 365},
#    {'value': 32, 'element': 342},
#    {'value': 27, 'element': 352},
#    {'value': 26, 'element': 369},
# ...

# %%
from datetime import date

today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2024-03-28

# %%
now = datetime.now()

# %%
fixtures_list['kickoff_time'] = pd.to_datetime(fixtures_list['kickoff_time']).dt.date

# %%
fixtures_list[fixtures_list['kickoff_time']> today]
# Out:
#         code  event  finished  finished_provisional   id kickoff_time  \
# 287  2367834   30.0     False                 False  297   2024-03-30
# 288  2367828   30.0     False                 False  292   2024-03-30
# 289  2367831   30.0     False                 False  294   2024-03-30
# 290  2367835   30.0     False                 False  298   2024-03-30
# 291  2367836   30.0     False                 False  299   2024-03-30
# ..       ...    ...       ...                   ...  ...          ...
# 375  2367913   38.0     False                 False  376   2024-05-19
# 376  2367914   38.0     False                 False  377   2024-05-19
# 377  2367915   38.0     False                 False  378   2024-05-19
# 378  2367916   38.0     False                 False  379   2024-05-19
# 379  2367917   38.0     False                 False  380   2024-05-19
#
#      minutes  provisional_start_time  started  team_a  team_a_score  team_h  \
# ...

# %%
fpl_data = pd.read_csv('/Users/ziadNader/Desktop/Personal Projects/Fantasy Premier League/data/Files/Players/2024-03-09_fpl_players.csv')

# %%
fpl_data.news
# Out:
# 0                                  Transferred to Monaco
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#                              ...
# 827                                                  NaN
# 828                                                  NaN
# 829    On loan to Villarreal until the end of the season
# 830                                                  NaN
# 831                                                  NaN
# Name: news, Length: 832, dtype: object

# %%
fpl_data.team_code
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 827    39
# 828    39
# 829    39
# 830    39
# 831    39
# Name: team_code, Length: 832, dtype: int64
